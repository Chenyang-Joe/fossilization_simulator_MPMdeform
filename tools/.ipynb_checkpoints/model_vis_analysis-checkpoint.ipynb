# %%
print("hello")
# Out:
# hello

# %%
import trimesh
import meshplot as mp
import os

# %%
model_path = os.path.join("..", "examples", "gorilla", "Gorilla-gorilla-gorilla-f-MCZ-26850-cranium-000387371.ply")
model_path = os.path.join("..", "examples", "gorilla", "gorilla_10000_deformed.obj")
print(model_path)
# Out:
# ../examples/gorilla/gorilla_10000_deformed.obj

# %%
mesh = trimesh.load(model_path)
vs = mesh.vertices
fs = mesh.faces

# %%
mp.plot(vs, fs)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.3534513…

# %%
print(len(mesh.vertices))
print(len(mesh.faces))
# Out:
# 9886
# 20000

# %%
model_path = os.path.join("..", "MPMPytorch_PC_example.obj")
model_path = "/local_data/cx2219/fossilization_simulator_MPMdeform/dev/eval_-0_536030596231002_0_8098605398836952_0_23832143387351068_0_05.obj"
mesh = trimesh.load(model_path)
vs = mesh.vertices
# fs = mesh.faces
# mp.plot(vs, fs)
mp.plot(vs)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.3272727…
